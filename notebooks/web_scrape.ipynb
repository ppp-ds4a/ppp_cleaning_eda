# %%
import pandas as pd
import re
import requests 
from bs4 import BeautifulSoup 
import time 
import random
import lxml

# %%
# Read in data from github
PATH = "https://raw.githubusercontent.com/ppp-ds4a/ppp_cleaning_eda/main/data/yelp_b_webscrape.csv"
df = pd.read_csv(PATH, index_col="Unnamed: 0")

# create combined col, and rank rows based on most seen zip
df = df[df["combined"].isnull() == False]
rank_d = dict(df["postal_code"].value_counts().rank(ascending=False))
df["rank"] = df["postal_code"].map(rank_d)
df = df.sort_values("rank")

print(df.shape)
df.head(5)
# Out:
# (209393, 9)
#                    business_id                            name  \
# 36390   uaHJQ7kHmLRXh-q626flrA             Las Vegas Radiology
# 111720  8C3i6-yHHriGE8abcacrgg             CSI: The Experience
# 194157  Mnf10SaW1-8O3zVF_S16Dg  The Sporting House Bar & Grill
# 5124    Bh3ADEeEtMIIMe6QgrEEKw                          Macy's
# 79517   JDDg0KzpWJOO68PfMqfJbg             LoLo Rugs and Gifts
#
#                                                   address       city state  \
# 36390                       3201 S Maryland Pkwy, Ste 102  Las Vegas    NV
# 111720                              3799 Las Vegas Blvd S  Las Vegas    NV
# 194157  New York New York Hotel and Casino, 3790 Las V...  Las Vegas    NV
# 5124               The Boulevard Mall, 3634 Maryland Pkwy  Las Vegas    NV
# 79517                      3623 S Las Vegas Blvd, Ste 222  Las Vegas    NV
#
#        postal_code  is_open                                  combined  rank
# 36390        89109        1             Las Vegas Radiology Las Vegas   1.0
# 111720       89109        1             CSI: The Experience Las Vegas   1.0
# 194157       89109        0  The Sporting House Bar & Grill Las Vegas   1.0
# 5124         89109        0                          Macy's Las Vegas   1.0
# 79517        89109        1             LoLo Rugs and Gifts Las Vegas   1.0

# %%
# Sort rows by most seen zip code 


# df.sort_values("rank").to_csv("yelp_webscrape.csv")

# %% [markdown]
# ### Using Regex to clean strings
#
# - Traditional pandas methods and built-in python functions cannot clean the text appropriately
# - Using multiple regular expressions can help filter text based on text patterns
# - 200 status codes mean OK
#
# ##### [Regular Expression Docs](https://docs.python.org/3/library/re.html#module-re)
#
# ##### [List of HTTPS Status Codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)

# %%
def regex_clean(x):
    """
    Text cleaner for removing unwanted chars and replacing with appropriate chars
    """

    x = x.title()

    # Patterns
    pat1 = '[&]' # replace '&' with 'And'
    pat2 = "[' . / - ` , _]" #chars to remove

    # Regex substitution
    x = re.sub(pat1, "And", x)
    x = re.sub(pat2, "", x)

    # Split by uppercase letter then join with hyphen
    x = "-".join(re.findall('[A-Z][^A-Z]*', x))

    return "https://www.yelp.com/biz/" + x

# %%
# %%time
# FUNCTION TEST

# Change to adjust sample size of test
SAMPLE_SIZE = 100

# Return a list of random samples from "combined" column
sample = [x for x in df["combined"][:SAMPLE_SIZE]]

print("Sample Length: ", len(sample))

# Collect results for statistic estimation
response_dict = {}
url_404_ls = []
url_404_index_ls = []
closed_open_ls = []

# loop through samples and clean and check for reponse codes
for x in range(len(sample)):
    # Delay next execution by random integer between 1-25
    time.sleep(random.randint(9,20))

    r = requests.get(regex_clean(sample[x]))

    if str(r) == '<Response [503]>':
        print(f"503 found at iteration: {x}")
        break
    
    # If 404 then continue
    if str(r) == '<Response [404]>':
        url_404_ls.append(regex_clean(sample[x]))
        url_404_index_ls.append(df[df["combined"].str.contains(sample[x])].index[0])
        continue


    if str(r) not in response_dict:
        response_dict[str(r)] = 1
    elif str(r) in response_dict:
        response_dict[str(r)] += 1
    
    # Try to find alert saying business is closed, if not then return "no", continue if no list returned (bad request) 
    try: 
        e = "no"
        closed = BeautifulSoup(r.text, "lxml").find_all("span", {"class": "raw__373c0__3rcx7"})[0].text

        if len(closed) == 0:
            continue
    except:
        closed = e

    # Save to list whether business is open or closed
    if closed == "Yelpers report this location has closed.":
        closed_open_ls.append(0)
    else:
        closed_open_ls.append(1)
# Out:
# Sample Length:  100
# 503 found at iteration: 0

# %%
closed_open_ls
sample
# Out:
# ['6600 Rue Saint-Jacques Montréal',
#  '33 University Sq, Ste 270 Madison',
#  '15560 N Frank Lloyd Wright Blvd Scottsdale',
#  '10049 Darrow Rd Twinsburg',
#  '3425 - 29th Street  NE, Suite 101 Calgary',
#  '401 E Oak St Mahomet',
#  '3199 S Eastern Ave Las Vegas',
#  '374 College Street Toronto',
#  '4701 Boulevard Lasalle Verdun',
#  '10415 Centrum Pkwy Pineville',
#  '2606 E Indian School Rd Phoenix',
#  '28795 Lake Rd Bay Village',
#  '23 College St Toronto',
#  '332 Center Ave Pittsburgh',
#  '160 Clairton Blvd Pittsburgh',
#  '4811 N 16th St, Ste 104 Phoenix',
#  '1402 Williamson St Madison',
#  '10530 Northeast Pkwy Matthews',
#  '27 Av Ruth Brampton',
#  '6475 N Decatur Blvd, Ste 175 Las Vegas',
#  '3225 W Gibson Ln Phoenix',
#  '16 W Horizon Rdg Pkwy, Ste 100 Henderson',
#  '15030 North Tatum Blvd, Ste 115 Phoenix',
#  '6599 E Thomas Rd Scottsdale',
#  '5915 S Rainbow Blvd, Ste 105 Las Vegas',
#  '3628 E Indian School Rd Phoenix',
#  '328 W Sahara Ave Las Vegas',
#  '305 W 4th St Charlotte',
#  '10752 N 89th Pl Scottsdale',
#  '302 N Gilbert Rd Gilbert',
#  '3730 Las Vegas Blvd S Las Vegas',
#  '3034 Don Mills Road Toronto',
#  '23623 N Scottsdale Scottsdale',
#  '3385 Babcock Blvd Pittsburgh',
#  '2060 E Baseline Rd Phoenix',
#  '3320 W Southern Ave, Ste 120 Phoenix',
#  '2031 McDaniel St, Ste 140 North Las Vegas',
#  '1420 Nevada Hwy Boulder City',
#  '1740 E. Broadway Rd, Ste 107 Tempe',
#  '12234 N 51st  Ave Glendale',
#  '9591 York Alpha Dr Ste 8 North Royalton',
#  '284 Orenda Road, Unit 10 Toronto',
#  '9120 Stange Ave Las Vegas',
#  '140 Carlton St. Toronto',
#  '2923 N 67th Pl, Ste 2 Scottsdale',
#  '50 Main Street Beeton',
#  '2405 E University Dr Tempe',
#  '4603 Library Rd Bethel Park',
#  '50 Kingston Road E Ajax',
#  '3060 N 68th St Scottsdale',
#  '21 Trinity Street Toronto',
#  '960 Clague Rd, Ste 1100B Westlake',
#  '3743 Las Vegas Blvd S Las Vegas',
#  '4855 E Warner Rd Phoenix',
#  '9960 Dufferin Street, Suite 11 Maple',
#  '3253 Kent Rd Stow',
#  '411 Seventh Ave, Ste 1207 Pittsburgh',
#  '26500 Cedar Rd Beachwood',
#  '560 McNeilly Rd Pittsburgh',
#  '6338 W Sahara Ave Las Vegas',
#  '811 W Liberty St Medina',
#  '3200 Polaris Ave Las Vegas',
#  ', Ste B Waxhaw',
#  '29225 Chagrin Blvd, Ste 300 Cleveland',
#  '8615 W Sahara Ave Las Vegas',
#  '4835 S Fort Apache, Ste K Las Vegas',
#  '10 Discovery Ridge Hill SW, Suite 902 Calgary',
#  '445 W Trade St Charlotte',
#  '3170 E Sunset Rd Las Vegas',
#  '7575 Hwy 73 Denver',
#  '15105 John J Delaney Dr Charlotte',
#  '106 W Lincoln Ave McDonald',
#  '2222 E Indian School Rd Phoenix',
#  '1091 Yonge Street Toronto',
#  '1691 Dundas Street W Toronto',
#  '8021 N 35th Ave Phoenix',
#  '1731 W Rose Garden Ln, Ste 8 Phoenix',
#  '818 W Broadway Rd, Ste 103 Tempe',
#  '9100 S McKemy St Tempe',
#  '377 Church St Toronto',
#  '1753 Golden Mile Hwy, Rte 286 Monroeville',
#  '205 E Warm Springs Rd, Ste 102 Las Vegas',
#  '7181 N Hualapai Way Las Vegas',
#  '1205 W Warm Springs Rd, Ste 101 Henderson',
#  '3751 S Clubhouse Dr Chandler',
#  '9358 W Williams Rd Tolleson',
#  '560 S Country Club Dr Mesa',
#  '34406 N 27th Dr, Ste 5-136 Phoenix',
#  '3655 Concord Pkwy S Concord',
#  '217 9th St Pittsburgh',
#  '3355 Las Vegas Blvd S Las Vegas',
#  '1940 Ellesmere Road Scarborough',
#  '1104 College Street Toronto',
#  '5000 Great Northern Mall North Olmsted',
#  '293 Spadina Avenue Toronto',
#  '10046 N 43rd Ave Glendale',
#  '917 Kriedeman Dr Stoughton',
#  '7208 E Cave Creek Rd Carefree',
#  '13016 N Cave Creek Rd Phoenix',
#  '10039 University City Blvd, Ste J Charlotte']

# %%
df[df["combined"].str.contains(sample[x])].index[0]
# Out:
# 191224

# %%
# Add URL's to orginal subbset of data used for experiment and save to CSV
df_save = df.iloc[[df[df["combined"].str.contains(sample[x])].index[0] for x in range(len(sample))]]
# df_save["url"] = url_404_ls
df_save["open"] = closed_open_ls
df_save.to_csv("url_open_close.csv")

# Look at first 20 rows
pd.read_csv("url_open_close.csv").sample(3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-987c10343e63> in <module>()
#       2 df_save = df.iloc[[df[df["combined"].str.contains(sample[x])].index[0] for x in range(len(sample))]]
#       3 # df_save["url"] = url_404_ls
# ----> 4 df_save["open"] = closed_open_ls
#       5 df_save.to_csv("url_open_close.csv")
#       6
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3042         else:
#    3043             # set column
# -> 3044             self._set_item(key, value)
#    3045
#    3046     def _setitem_slice(self, key: slice, value):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3118         """
#    3119         self._ensure_valid_index(value)
# -> 3120         value = self._sanitize_column(key, value)
#    3121         NDFrame._set_item(self, key, value)
#    3122
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3766
#    3767             # turn me into an ndarray
# -> 3768             value = sanitize_index(value, self.index)
#    3769             if not isinstance(value, (np.ndarray, Index)):
#    3770                 if isinstance(value, list) and len(value) > 0:
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/construction.py in sanitize_index(data, index)
#     746     if len(data) != len(index):
#     747         raise ValueError(
# --> 748             "Length of values "
#     749             f"({len(data)}) "
#     750             "does not match length of index "
#
# ValueError: Length of values (81) does not match length of index (100)

# %% [markdown]
# ### Reponse 503 means overloaded service and the halt is temporary.

# %%
print(f"Reponse Dictionary: {response_dict}\n")

# Calculate percentage of successful responses
stat_val = response_dict['<Response [200]>'] / sum(response_dict.values())
print(f"Average 'Reponse 200' over {SAMPLE_SIZE} samples: {stat_val}")
# Out:
# Reponse Dictionary: {'<Response [200]>': 10}
#
# Average 'Reponse 200' over 10 samples: 1.0

# %% [markdown]
# ### How many unique URL's
#
# - Lower number of URL than number of original shape could be due too multiple places have the same web address like Franchises, Multiple locations, same owners, etc...

# %%
URL = "https://www.yelp.com/biz/skin-factory-tattoo-and-body-piercing-las-vegas" #closed
# URL = "https://www.yelp.com/biz/othello-wok-and-teriyaki-seattle" #open

r = requests.get(URL)
print(r)
BeautifulSoup(r.text, "lxml").find_all(
    "span", {"class": "raw__373c0__3rcx7"}
    )[0].text
# Out:
# <Response [200]>
# 'Yelpers report this location has closed.'

# %%
# How many unique addresses
df["combined"].apply(regex_clean).nunique()
# Out:
# 183044

# %% [markdown]
# ### Identify Closed Banners on yelp pages
#
# - Create functionality that looks for a closed banner determined by users and return a 0 or 1 based on whether the business is closed or open.
#
# <p align="center">
#   <img width="500" height="400" src="https://imgur.com/P1hZDTY.png">
# </p>

# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in /usr/local/lib/python3.6/dist-packages (4.2.6)

# %%
PATH = "https://raw.githubusercontent.com/ppp-ds4a/ppp_cleaning_eda/main/data/under150k.csv"
df = pd.read_csv(PATH)
df.head(3)
# Out:
#    Unnamed: 0  ...                           2017 NAICS Title
# 0           0  ...  Hotels (except Casino Hotels) and Motels
# 1           1  ...                              Machine Shops
# 2           2  ...                     Architectural Services
#
# [3 rows x 11 columns]

# %%
soup.find_all("span", {"class": "raw__373c0__3rcx7"})
# Out:
# []

# %%
<div class=" alert-icon-unit__373c0__2WHUe arrange-unit__373c0__o3tjT border-color--default__373c0__3-ifU"><div class=" alert-icon-container__373c0__2Vlsq border-color--default__373c0__3-ifU"><div class=" alert-icon__373c0__5A99z border-color--default__373c0__3-ifU"><span aria-hidden="true" class="icon--24-exclamation-v2 css-p5yz4n"><svg xmlns="http://www.w3.org/2000/svg" width="24" height="24" class="icon_svg"><path d="M12 1c6.075 0 11 4.925 11 11a11 11 0 01-11 11C5.925 23 1 18.075 1 12S5.925 1 12 1zm0 2a9 9 0 100 18 9 9 0 000-18zm0 11.39a1.5 1.5 0 110 3 1.5 1.5 0 010-3zm0-8.78a1 1 0 011 1v5.63a1 1 0 11-2 0V6.61a1 1 0 011-1z"></path></svg></span></div></div></div>
# Out:
# [<div id="fb-root"></div>, <div class="lang-en" id="wrap">
#  <div class="page-header">
#  <yelp-react-root>
#  <div data-hypernova-id="ea2d8cf5-4342-4122-acfc-f54e33e204ed" data-hypernova-key="yelp_mainwww__dd7c71eacf58e5a2091de2f128716d4e89c5cc50__yelp_mainwww__ConsumerHeader__yelp_mainwww"></div>
#  <script data-hypernova-id="ea2d8cf5-4342-4122-acfc-f54e33e204ed" data-hypernova-key="yelp_mainwww__dd7c71eacf58e5a2091de2f128716d4e89c5cc50__yelp_mainwww__ConsumerHeader__yelp_mainwww" type="application/json"><!--{"currentURL": "https://www.yelp.com/biz/skin-factory-tattoo-and-body-piercing-las-vegas", "userData": null, "initialHiddenLocationInputName": "find_loc", "gaConfig": {"metrics": {"www": {}, "global": {}}, "domain": "yelp.com", "user_id": null, "dimensions": {"www": {"www_second_page_pitch": [111, "status_quo"], "www_search_snippets_in_sync_with_ads": [112, "status_quo_8"], "contributions.www.remove_review_draft_modules": [183, "status_quo"], "readerx.web.biz_for_services": [116, "biz_status_quo"], "ytp_eat24_yelp_style_to_iframe": [136, "enabled"], "viewport_tracking": [29, null], "distil": [53, null], "internal_ip": [27, "False"], "messaging.www.yelp_guaranteed": [160, "status_quo"], "styleguide_buttons": [13, "status_quo"], "account_level": [1, "anon"], "searchux.www.services_serp_card_new_layout_v0_0": [151, "status_quo"], "service": [107, "yelp-main"], "content_country": [15, "US"], "integration": [14, ""], "ytp_order_confirmation_page": [143, "enabled"], "messaging.www.composer_notifications_spam_and_hover_state": [177, "notifications_enabled"], "lsm.www.unpakt_cta_change": [108, "unpakt_cta_enabled"], "readerx.web.popular_dishes": [198, "highlights_popular_dishes"], "full_url": [34, "/biz/skin-factory-tattoo-and-body-piercing-las-vegas"], "known_bot": [186, "other"], "remote_ip": [4, "35.238.180.0"], "distil_js_enabled": [138, null], "contributions.www.war_compose_redesign": [6, "enabled"], "www_biz_details_raq_sticky": [84, "enabled"], "lsat.www.dropdown_header": [54, "enabled"], "ad.web_carousel_bottom_of_biz": [78, "status_quo"], "messaging.www.show_city_in_multibiz": [77, "enabled"], "yr_diner.www.direct_checkout_for_exact_match": [163, "disabled"], "contributions.www.war_compose_recent_photos": [102, "enabled"], "messaging.www.raq_cards_on_search": [61, "status_quo"], "lsmoney.www.yg_raq_cards_on_search": [152, "status_quo"], "payment.ux.www": [197, "enabled"], "review_actions_dropdown": [2, "disabled"], "lower_promoted_delivery_threshold": [58, "reduced_to_fifteen"], "platform_pickup_filter": [20, "enabled"], "www_education_banner": [190, "disabled"], "www_current_location_suggestion": [185, "enabled"], "pagelet_mode_www_biz_details": [24, "allow_async"], "styleguide_typography": [159, "status_quo"], "ytp_delivery_landing": [125, "platform_pages"], "referrer": [64, "none"], "contributions.www.war_compose_signup": [148, "disabled"], "is_biz_user": [129, "False"], "contributions.www.war_attach_photos": [99, "enabled"], "www_signup_redesign": [92, "status_quo"], "nowait_restaurant.www.no_wait_message": [106, "show_waitlist_instructions"], "txn.www.checkout_page_changes": [135, "enabled"], "decrypted_yuv_id": [3, "70B1ADACEC3CD251"], "eat24_free_delivery_banner": [45, "disabled"]}, "global": {"distil_js_enabled": [13, null], "referrer": [28, "none"], "content_country": [11, "US"], "integration": [17, ""], "distil": [12, null], "internal_ip": [18, "False"], "full_url": [15, "/biz/skin-factory-tattoo-and-body-piercing-las-vegas"], "known_bot": [36, "other"], "account_level": [1, "anon"]}}, "enable_high_volume_events": false, "trackers": {"www": "UA-30501-24", "global": "UA-30501-1"}, "js_dimensions": {"www": {"platform_order_type": [127, null], "js_vertical_search_type": [39, null]}, "global": {}}, "ga_enabled": true, "clientID": "70B1ADACEC3CD251"}, "holidayModifier": null, "initialSearchDisplayVal": "", "bizSiteURL": null, "logoutCsrfToken": "db7ae0e96aefbdb9710eb8ba3833d6c669d38f2c7947d0632828c63b12acf619", "initialIsCurrentLocation": false, "rightLinksData": [{"iconName": "IconPencil24", "platform": "desktop", "promo": null, "text": "Write a Review", "dropdownLinksData": [], "alias": "writeareview", "href": "/writeareview"}, {"iconName": "IconBizhouse24", "platform": "desktop", "promo": null, "text": "For  ...
#  </yelp-react-root>
#  <script nonce="984c7d92">
#              (function() {
#                  var main = null;
#
#                  var main=(function(){function a(b){window.yDFP.ABP={};window.yDFP.ABP.getPixelSource=function(c){return b+"?ch="+c+"&rn="+Math.random()*11};window.yDFP.ABP.detect=function(l){var g=false;var f=2;var i=false;var h=false;function k(n,m){if(f===0||m>400){n(f===0&&g)}else{setTimeout(function(){k(n,m*2)},m*2)}}function j(){if(f!==0){return}g=!i&&h}var e=function(){f-=1;j()};var d=new Image();d.onload=e;d.onerror=function(){i=true;e()};d.src=window.yDFP.ABP.getPixelSource(1);var c=new Image();c.onload=e;
#  c.onerror=function(){h=true;e()};c.src=window.yDFP.ABP.getPixelSource(2);k(l,100)};window.yDFP.ABP.abpInstalledChannel="1382551876";window.yDFP.ABP.abpNotInstalledChannel="2859285073"}window.yDFP=window.yDFP||{};window.yDFP.initABPDetection=a;return window.yDFP.initABPDetection})();
#
#                  if (main === null) {
#                      throw 'invalid inline script, missing main declaration.';
#                  }
#                  main("/px.gif");
#              })();
#      </script>
#  <div id="print-masthead">
#  <img alt="Yelp" class="print-bkg-img" src="https://s3-media0.fl.yelpcdn.com/assets/2/www/img/b7e9d647188d/gfx/header_print.gif"/>
#  </div>
#  </div>
#  <span class="offscreen" id="page-content"> </span>
#  <div class="content-container js-biz-details">
#  <div id="alert-container">
#  </div>
#  </div>
#  <div class="main-content-wrap main-content-wrap--full">
#  <yelp-react-root>
#  <div data-hypernova-id="497ddde1-a311-4a55-aa96-dc69e073f082" data-hypernova-key="yelp_mainwww__dd7c71eacf58e5a2091de2f128716d4e89c5cc50__yelp_mainwww__BizDetailsApp__yelp_mainwww"></div>
#  <script data-hypernova-id="497ddde1-a311-4a55-aa96-dc69e073f082" data-hypernova-key="yelp_mainwww__dd7c71eacf58e5a2091de2f128716d4e89c5cc50__yelp_mainwww__BizDetailsApp__yelp_mainwww" type="application/json"><!--{"gaConfig": {"metrics": {"www": {}, "global": {}}, "domain": "yelp.com", "user_id": null, "dimensions": {"www": {"www_second_page_pitch": [111, "status_quo"], "rating": [114, 4.5], "www_search_snippets_in_sync_with_ads": [112, "status_quo_8"], "biz_closed": [8, "True"], "contributions.www.remove_review_draft_modules": [183, "status_quo"], "readerx.web.biz_for_services": [116, "biz_status_quo"], "ytp_eat24_yelp_style_to_iframe": [136, "enabled"], "viewport_tracking": [29, null], "distil": [53, null], "internal_ip": [27, "False"], "messaging.www.yelp_guaranteed": [160, "status_quo"], "styleguide_buttons": [13, "status_quo"], "yelp.www.biz_details.lazy_loading.enabled": [25, "false"], "account_level": [1, "anon"], "searchux.www.services_serp_card_new_layout_v0_0": [151, "status_quo"], "service": [107, "yelp-main"], "content_country": [15, "US"], "integration": [14, ""], "nowait_restaurant.www.no_wait_message": [106, "show_waitlist_instructions"], "ytp_order_confirmation_page": [143, "enabled"], "messaging.www.composer_notifications_spam_and_hover_state": [177, "notifications_enabled"], "lsm.www.unpakt_cta_change": [108, "unpakt_cta_enabled"], "readerx.web.popular_dishes": [198, "highlights_popular_dishes"], "full_url": [34, "/biz/skin-factory-tattoo-and-body-piercing-las-vegas"], "known_bot": [186, "other"], "remote_ip": [4, "35.238.180.0"], "distil_js_enabled": [138, null], "second_level_categories": [110, "tattoo, piercing"], "yr_diner.www.direct_checkout_for_exact_match": [163, "disabled"], "contributions.www.war_compose_redesign": [6, "enabled"], "has_canonical": [36, "False"], "www_biz_details_raq_sticky": [84, "enabled"], "lsat.www.dropdown_header": [54, "enabled"], "business_id": [141, "8Qkh1QlRYZXOCxUrsrcHfw"], "biz_review_count": [10, "100+"], "ad.web_carousel_bottom_of_biz": [78, "status_quo"], "is_indexable": [42, "True"], "contributions.www.war_compose_recent_photos": [102, "enabled"], "messaging.www.raq_cards_on_search": [61, "status_quo"], "lsmoney.www.yg_raq_cards_on_search": [152, "status_quo"], "messaging.www.show_city_in_multibiz": [77, "enabled"], "payment.ux.www": [197, "enabled"], "review_actions_dropdown": [2, "disabled"], "lower_promoted_delivery_threshold": [58, "reduced_to_fifteen"], "platform_pickup_filter": [20, "enabled"], "www_education_banner": [190, "disabled"], "www_current_location_suggestion": [185, "enabled"], "pagelet_mode_www_biz_details": [24, "allow_async"], "styleguide_typography": [159, "status_quo"], "ytp_delivery_landing": [125, "platform_pages"], "referrer": [64, "none"], "contributions.www.war_compose_signup": [148, "disabled"], "top_level_categories": [11, "beautysvc"], "is_biz_user": [129, "False"], "contributions.www.war_attach_photos": [99, "enabled"], "www_signup_redesign": [92, "status_quo"], "biz_city_state": [192, "Las Vegas, NV"], "category_paths_to_root": [94, "[['tattoo', 'beautysvc'], ['piercing', 'beautysvc']]"], "txn.www.checkout_page_changes": [135, "enabled"], "eat24_free_delivery_banner": [45, "disabled"], "decrypted_yuv_id": [3, "70B1ADACEC3CD251"]}, "global": {"distil_js_enabled": [13, null], "rating": [27, 4.5], "biz_closed": [4, "True"], "is_indexable": [19, "True"], "referrer": [28, "none"], "has_canonical": [16, "False"], "content_country": [11, "US"], "integration": [17, ""], "biz_review_count": [6, "100+"], "top_level_categories": [7, "beautysvc"], "distil": [12, null], "internal_ip": [18, "False"], "category_paths_to_root": [10, "[['tattoo', 'beautysvc'], ['piercing', 'beautysvc']]"], "full_url": [15, "/biz/skin-factory-tattoo-and-body-piercing-las-vegas"], "known_bot": [36, "other"], "account_level": [1, "anon"]}}, "enable_high_volume_events": false, "trackers": {"www": "UA-30501-24", "global": "UA-30501-1"}, "js_dimensions": {"www": {"platform_orde ...
#  </yelp-react-root>
#  </div>
#  <script nonce="984c7d92">
#              (function() {
#                  var main = null;
#
#                  var main=function(a){adroll_adv_id="adroll_adv_id" in a.custom_data?a.custom_data.adroll_adv_id:"BHPKS4B4ONEJJMGH4QCJZR";adroll_pix_id="adroll_pix_id" in a.custom_data?a.custom_data.adroll_pix_id:"QB5JPFIKRZDSBOZSULG4YB";adroll_user_identifier=a.user_identifier;adroll_email=a.hashed_email;adroll_shop_id="biz_id" in a.custom_data?a.custom_data.biz_id:undefined;window.adroll_callbacks=[function(){if(a.redirect_url){setTimeout(function(){location.replace(a.redirect_url)},"redirect_wait_time_in_seconds" in a?a.redirect_wait_time_in_seconds*1000:0)
#  }}];(function(){var b=function(){if(document.readyState&&!/loaded|complete/.test(document.readyState)){setTimeout(b,10);return}if(!window.__adroll_loaded){__adroll_loaded=true;setTimeout(b,50);return}var d=document.createElement("script");var c="https://s.adroll.com";d.setAttribute("async","true");d.type="text/javascript";d.src=c+"/j/roundtrip.js";((document.getElementsByTagName("head")||[null])[0]||document.getElementsByTagName("script")[0].parentNode).appendChild(d)};if(window.addEventListener){window.addEventListener("load",b,false)
#  }else{window.attachEvent("onload",b)}}());adroll_custom_data=a.custom_data};
#
#                  if (main === null) {
#                      throw 'invalid inline script, missing main declaration.';
#                  }
#                  main({"user_identifier": null, "hashed_email": null, "custom_data": {"adroll_geoquad_v1": 406836, "user_type": 0, "biz_id": "8Qkh1QlRYZXOCxUrsrcHfw", "city": "Las Vegas", "category_aliases": "beautysvc,piercing,tattoo", "is_checkout": null, "flow": "biz_details", "brand_names": null, "price_tags": "2", "state": "NV", "guv": "70B1ADACEC3CD251"}});
#              })();
#      </script>
#  <script>            var __nspid="1fkzhx1";
#              var __pulsarjsintegrity="sha256-irwpY+USSKJUVujjm/bmigzpRVB421Nf6qWDGD4uSGA=";
#              var __nsptags=[];
#              (function(w, d) { var x = function() {
#              var j=d.createElement("script");j.type="text/javascript";j.async=true;
#              j.src="http"+("https:"===d.location.protocol?"s://cs":"://c")+".ns1p.net/p.js?a="+__nspid;
#              j.integrity=__pulsarjsintegrity;j.crossOrigin="anonymous";d.body.appendChild(j); }
#              if(w.addEventListener) { w.addEventListener("load", x, false); }
#              else if(w.attachEvent) { w.attachEvent("onload", x); }
#              else { w.onload = x; }
#              }(window, document));
#  </script>
#  <!-- <a href="/biz/outlook-autumn-market-fundamental-catwalk-flimsy-roost-legibility-individualism-grocer-predestination-9">yelp</a> -->
#  <div id="page-popups" style="display: none;">
#  </div>
#  </div>, <div class="page-header">
#  <yelp-react-root>
#  <div data-hypernova-id="ea2d8cf5-4342-4122-acfc-f54e33e204ed" data-hypernova-key="yelp_mainwww__dd7c71eacf58e5a2091de2f128716d4e89c5cc50__yelp_mainwww__ConsumerHeader__yelp_mainwww"></div>
#  <script data-hypernova-id="ea2d8cf5-4342-4122-acfc-f54e33e204ed" data-hypernova-key="yelp_mainwww__dd7c71eacf58e5a2091de2f128716d4e89c5cc50__yelp_mainwww__ConsumerHeader__yelp_mainwww" type="application/json"><!--{"currentURL": "https://www.yelp.com/biz/skin-factory-tattoo-and-body-piercing-las-vegas", "userData": null, "initialHiddenLocationInputName": "find_loc", "gaConfig": {"metrics": {"www": {}, "global": {}}, "domain": "yelp.com", "user_id": null, "dimensions": {"www": {"www_second_page_pitch": [111, "status_quo"], "www_search_snippets_in_sync_with_ads": [112, "status_quo_8"], "contributions.www.remove_review_draft_modules": [183, "status_quo"], "readerx.web.biz_for_services": [116, "biz_status_quo"], "ytp_eat24_yelp_style_to_iframe": [136, "enabled"], "viewport_tracking": [29, null], "distil": [53, null], "internal_ip": [27, "False"], "messaging.www.yelp_guaranteed": [160, "status_quo"], "styleguide_buttons": [13, "status_quo"], "account_level": [1, "anon"], "searchux.www.services_serp_card_new_layout_v0_0": [151, "status_quo"], "service": [107, "yelp-main"], "content_country": [15, "US"], "integration": [14, ""], "ytp_order_confirmation_page": [143, "enabled"], "messaging.www.composer_notifications_spam_and_hover_state": [177, "notifications_enabled"], "lsm.www.unpakt_cta_change": [108, "unpakt_cta_enabled"], "readerx.web.popular_dishes": [198, "highlights_popular_dishes"], "full_url": [34, "/biz/skin-factory-tattoo-and-body-piercing-las-vegas"], "known_bot": [186, "other"], "remote_ip": [4, "35.238.180.0"], "distil_js_enabled": [138, null], "contributions.www.war_compose_redesign": [6, "enabled"], "www_biz_details_raq_sticky": [84, "enabled"], "lsat.www.dropdown_header": [54, "enabled"], "ad.web_carousel_bottom_of_biz": [78, "status_quo"], "messaging.www.show_city_in_multibiz": [77, "enabled"], "yr_diner.www.direct_checkout_for_exact_match": [163, "disabled"], "contributions.www.war_compose_recent_photos": [102, "enabled"], "messaging.www.raq_cards_on_search": [61, "status_quo"], "lsmoney.www.yg_raq_cards_on_search": [152, "status_quo"], "payment.ux.www": [197, "enabled"], "review_actions_dropdown": [2, "disabled"], "lower_promoted_delivery_threshold": [58, "reduced_to_fifteen"], "platform_pickup_filter": [20, "enabled"], "www_education_banner": [190, "disabled"], "www_current_location_suggestion": [185, "enabled"], "pagelet_mode_www_biz_details": [24, "allow_async"], "styleguide_typography": [159, "status_quo"], "ytp_delivery_landing": [125, "platform_pages"], "referrer": [64, "none"], "contributions.www.war_compose_signup": [148, "disabled"], "is_biz_user": [129, "False"], "contributions.www.war_attach_photos": [99, "enabled"], "www_signup_redesign": [92, "status_quo"], "nowait_restaurant.www.no_wait_message": [106, "show_waitlist_instructions"], "txn.www.checkout_page_changes": [135, "enabled"], "decrypted_yuv_id": [3, "70B1ADACEC3CD251"], "eat24_free_delivery_banner": [45, "disabled"]}, "global": {"distil_js_enabled": [13, null], "referrer": [28, "none"], "content_country": [11, "US"], "integration": [17, ""], "distil": [12, null], "internal_ip": [18, "False"], "full_url": [15, "/biz/skin-factory-tattoo-and-body-piercing-las-vegas"], "known_bot": [36, "other"], "account_level": [1, "anon"]}}, "enable_high_volume_events": false, "trackers": {"www": "UA-30501-24", "global": "UA-30501-1"}, "js_dimensions": {"www": {"platform_order_type": [127, null], "js_vertical_search_type": [39, null]}, "global": {}}, "ga_enabled": true, "clientID": "70B1ADACEC3CD251"}, "holidayModifier": null, "initialSearchDisplayVal": "", "bizSiteURL": null, "logoutCsrfToken": "db7ae0e96aefbdb9710eb8ba3833d6c669d38f2c7947d0632828c63b12acf619", "initialIsCurrentLocation": false, "rightLinksData": [{"iconName": "IconPencil24", "platform": "desktop", "promo": null, "text": "Write a Review", "dropdownLinksData": [], "alias": "writeareview", "href": "/writeareview"}, {"iconName": "IconBizhouse24", "platform": "desktop", "promo": null, "text": "For  ...
#  </yelp-react-root>
#  <script nonce="984c7d92">
#              (function() {
#                  var main = null;
#
#                  var main=(function(){function a(b){window.yDFP.ABP={};window.yDFP.ABP.getPixelSource=function(c){return b+"?ch="+c+"&rn="+Math.random()*11};window.yDFP.ABP.detect=function(l){var g=false;var f=2;var i=false;var h=false;function k(n,m){if(f===0||m>400){n(f===0&&g)}else{setTimeout(function(){k(n,m*2)},m*2)}}function j(){if(f!==0){return}g=!i&&h}var e=function(){f-=1;j()};var d=new Image();d.onload=e;d.onerror=function(){i=true;e()};d.src=window.yDFP.ABP.getPixelSource(1);var c=new Image();c.onload=e;
#  c.onerror=function(){h=true;e()};c.src=window.yDFP.ABP.getPixelSource(2);k(l,100)};window.yDFP.ABP.abpInstalledChannel="1382551876";window.yDFP.ABP.abpNotInstalledChannel="2859285073"}window.yDFP=window.yDFP||{};window.yDFP.initABPDetection=a;return window.yDFP.initABPDetection})();
#
#                  if (main === null) {
#                      throw 'invalid inline script, missing main declaration.';
#                  }
#                  main("/px.gif");
#              })();
#      </script>
#  <div id="print-masthead">
#  <img alt="Yelp" class="print-bkg-img" src="https://s3-media0.fl.yelpcdn.com/assets/2/www/img/b7e9d647188d/gfx/header_print.gif"/>
#  </div>
#  </div>, <div data-hypernova-id="ea2d8cf5-4342-4122-acfc-f54e33e204ed" data-hypernova-key="yelp_mainwww__dd7c71eacf58e5a2091de2f128716d4e89c5cc50__yelp_mainwww__ConsumerHeader__yelp_mainwww"></div>, <div id="print-masthead">
#  <img alt="Yelp" class="print-bkg-img" src="https://s3-media0.fl.yelpcdn.com/assets/2/www/img/b7e9d647188d/gfx/header_print.gif"/>
#  </div>, <div class="content-container js-biz-details">
#  <div id="alert-container">
#  </div>
#  </div>, <div id="alert-container">
#  </div>, <div class="main-content-wrap main-content-wrap--full">
#  <yelp-react-root>
#  <div data-hypernova-id="497ddde1-a311-4a55-aa96-dc69e073f082" data-hypernova-key="yelp_mainwww__dd7c71eacf58e5a2091de2f128716d4e89c5cc50__yelp_mainwww__BizDetailsApp__yelp_mainwww"></div>
#  <script data-hypernova-id="497ddde1-a311-4a55-aa96-dc69e073f082" data-hypernova-key="yelp_mainwww__dd7c71eacf58e5a2091de2f128716d4e89c5cc50__yelp_mainwww__BizDetailsApp__yelp_mainwww" type="application/json"><!--{"gaConfig": {"metrics": {"www": {}, "global": {}}, "domain": "yelp.com", "user_id": null, "dimensions": {"www": {"www_second_page_pitch": [111, "status_quo"], "rating": [114, 4.5], "www_search_snippets_in_sync_with_ads": [112, "status_quo_8"], "biz_closed": [8, "True"], "contributions.www.remove_review_draft_modules": [183, "status_quo"], "readerx.web.biz_for_services": [116, "biz_status_quo"], "ytp_eat24_yelp_style_to_iframe": [136, "enabled"], "viewport_tracking": [29, null], "distil": [53, null], "internal_ip": [27, "False"], "messaging.www.yelp_guaranteed": [160, "status_quo"], "styleguide_buttons": [13, "status_quo"], "yelp.www.biz_details.lazy_loading.enabled": [25, "false"], "account_level": [1, "anon"], "searchux.www.services_serp_card_new_layout_v0_0": [151, "status_quo"], "service": [107, "yelp-main"], "content_country": [15, "US"], "integration": [14, ""], "nowait_restaurant.www.no_wait_message": [106, "show_waitlist_instructions"], "ytp_order_confirmation_page": [143, "enabled"], "messaging.www.composer_notifications_spam_and_hover_state": [177, "notifications_enabled"], "lsm.www.unpakt_cta_change": [108, "unpakt_cta_enabled"], "readerx.web.popular_dishes": [198, "highlights_popular_dishes"], "full_url": [34, "/biz/skin-factory-tattoo-and-body-piercing-las-vegas"], "known_bot": [186, "other"], "remote_ip": [4, "35.238.180.0"], "distil_js_enabled": [138, null], "second_level_categories": [110, "tattoo, piercing"], "yr_diner.www.direct_checkout_for_exact_match": [163, "disabled"], "contributions.www.war_compose_redesign": [6, "enabled"], "has_canonical": [36, "False"], "www_biz_details_raq_sticky": [84, "enabled"], "lsat.www.dropdown_header": [54, "enabled"], "business_id": [141, "8Qkh1QlRYZXOCxUrsrcHfw"], "biz_review_count": [10, "100+"], "ad.web_carousel_bottom_of_biz": [78, "status_quo"], "is_indexable": [42, "True"], "contributions.www.war_compose_recent_photos": [102, "enabled"], "messaging.www.raq_cards_on_search": [61, "status_quo"], "lsmoney.www.yg_raq_cards_on_search": [152, "status_quo"], "messaging.www.show_city_in_multibiz": [77, "enabled"], "payment.ux.www": [197, "enabled"], "review_actions_dropdown": [2, "disabled"], "lower_promoted_delivery_threshold": [58, "reduced_to_fifteen"], "platform_pickup_filter": [20, "enabled"], "www_education_banner": [190, "disabled"], "www_current_location_suggestion": [185, "enabled"], "pagelet_mode_www_biz_details": [24, "allow_async"], "styleguide_typography": [159, "status_quo"], "ytp_delivery_landing": [125, "platform_pages"], "referrer": [64, "none"], "contributions.www.war_compose_signup": [148, "disabled"], "top_level_categories": [11, "beautysvc"], "is_biz_user": [129, "False"], "contributions.www.war_attach_photos": [99, "enabled"], "www_signup_redesign": [92, "status_quo"], "biz_city_state": [192, "Las Vegas, NV"], "category_paths_to_root": [94, "[['tattoo', 'beautysvc'], ['piercing', 'beautysvc']]"], "txn.www.checkout_page_changes": [135, "enabled"], "eat24_free_delivery_banner": [45, "disabled"], "decrypted_yuv_id": [3, "70B1ADACEC3CD251"]}, "global": {"distil_js_enabled": [13, null], "rating": [27, 4.5], "biz_closed": [4, "True"], "is_indexable": [19, "True"], "referrer": [28, "none"], "has_canonical": [16, "False"], "content_country": [11, "US"], "integration": [17, ""], "biz_review_count": [6, "100+"], "top_level_categories": [7, "beautysvc"], "distil": [12, null], "internal_ip": [18, "False"], "category_paths_to_root": [10, "[['tattoo', 'beautysvc'], ['piercing', 'beautysvc']]"], "full_url": [15, "/biz/skin-factory-tattoo-and-body-piercing-las-vegas"], "known_bot": [36, "other"], "account_level": [1, "anon"]}}, "enable_high_volume_events": false, "trackers": {"www": "UA-30501-24", "global": "UA-30501-1"}, "js_dimensions": {"www": {"platform_orde ...
#  </yelp-react-root>
#  </div>, <div data-hypernova-id="497ddde1-a311-4a55-aa96-dc69e073f082" data-hypernova-key="yelp_mainwww__dd7c71eacf58e5a2091de2f128716d4e89c5cc50__yelp_mainwww__BizDetailsApp__yelp_mainwww"></div>, <div id="page-popups" style="display: none;">
#  </div>, <div id="ttdUniversalPixelTag290e816a69e9439f960a9588bc2ffb54" style="display:none">
#  <script src="https://js.adsrvr.org/up_loader.1.1.0.js" type="text/javascript"></script>
#  <script nonce="984c7d92">
#              (function() {
#                  var main = null;
#
#                  var main=function(){(function(b){if(typeof TTDUniversalPixelApi==="function"){var a=new TTDUniversalPixelApi();a.init("igcouad",["mvh4ai1"],"https://insight.adsrvr.org/track/up","ttdUniversalPixelTag290e816a69e9439f960a9588bc2ffb54")}})(this)};
#
#                  if (main === null) {
#                      throw 'invalid inline script, missing main declaration.';
#                  }
#                  main();
#              })();
#      </script>
#  </div>]

# %%
soup.text
# Out:
# ' \n\n\n            (function() {\n                var main = null;\n\n                var main=function(){window.onerror=function(k,a,c,i,f){var j=(document.getElementsByTagName("html")[0].getAttribute("webdriver")==="true"||navigator.userAgent==="selenium");var h=f&&(f.name==="ServerSideRenderingError"||f.name==="CSRFallbackError");if(j&&!h){document.body.innerHTML="<h1>Javascript Error Detected</h1>";var g=document.createElement("div");g.setAttribute("id","pastebinTraceback");var d=document.createElement("code");var e={message:k,source:a,lineno:c,colno:i,error:f};var b=document.createTextNode("JS ERROR DETECTED\\n"+window.JSON.stringify(e,null,2));\nd.appendChild(b);g.appendChild(d);document.getElementsByTagName("body")[0].appendChild(g)}}};\n\n                if (main === null) {\n                    throw \'invalid inline script, missing main declaration.\';\n                }\n                main();\n            })();\n    \n\n\n\n\n\n\n\n\n\n            window.yPageStart = new Date().getTime();\n\n            var initialVisibilityState = document.webkitVisibilityState;\n\n                yPerfTimings = [];\n\n                ySitRepParams = {"clientIP": "35.238.180.183", "datacenter": "us-east-1", "is_internal_ip": false, "edgeStartTime": 1610763280138715, "cfRayID": null, "site": "main", "serverStartTime": 1610763280157, "action": null, "edgestageSubdomain": "_disabled", "disableBeacon": false, "b3Sampled": "0", "uniqueRequestID": "42b20fcc2ca7e66f", "isLoggedIn": false, "zipkinTraceID": "d67458a7387425c8", "servlet": "biz_details", "yuv_record": "Ph-FZIr8QpvF9j8QX19WUO3Ews3pNWlKUy9VIxNE7IblbO5j_jfH4OZXK7kHVT10ewcIWBycxG9pd0C8EcQQ6j1gpPl4f4J4"};\n                window.ySitRepParams[\'initialVisibilityState\'] = initialVisibilityState;\n                window.ySitRepParams[\'seoCohorts\'] = [["traffic_pagination_seo_experiment", "indexed_pagination_1"], ["biz_site_new_business_user_onboarding", "status_quo"], ["traffic_desc_search_title_last_updated_experiment", "with_last_updated_1"], ["traffic_search_url_normalization_experiment_v3", "status_quo_01"], ["biz_site_self_serve_cpc_re_v2", "00_status_quo"], ["www_boi_holdout_experiment_2020_q1", "prompts_enabled"], ["contributions.biz_owner_respond_to_new_review_email", "enabled"], ["traffic_nearme_optimization_experiment", "treatment"], ["traffic_internal_linking_biz_details_to_raq_searches", "enabled"], ["traffic_main_biz_experiment_toggle", null], ["www_boi_modal_callouts_v2", "claim_biz_for_free"], ["traffic_search_internal_linking_service_offerings", "linked_1"], ["traffic_search_internal_linking_top_searches", "linked_0"], ["biz_site_yes_it_works_rollout", "yiw_impression_and_clicks_enabled"], ["biz_growth.biz_site_verify_with_work_email_v2", "enabled"], ["biz_growth.category_specific_claim_callouts", "status_quo"], ["traffic_search_internal_linking_experiment_v2", "linked_1"], ["traffic_index_new_pages_cross_validation", "cv_group"], ["traffic_search_internal_linking_home_cleaning", "linked_0"], ["traffic_top_searches_for_sitemap", "status_quo_0"], ["traffic_nearme_smart_banner_experiment", "smart_banner"], ["www_biz_owner_identification", "v5"], ["traffic_critical_css_on_msite", "conservative_2"], ["traffic_search_url_normalization", "enabled"], ["traffic_remove_cdn_sharding_exp", "remove_cdn_sharding_0"], ["yelp.www.search.traffic_bunsen_calibration_experiment", "NA_cohort_allocation_comes_from_bunsen"], ["traffic_top_searches_through_cordite", "disabled"], ["amp_biz_details", "status_quo"], ["biz_conditional_raq_title_experiment", "raq_ruleset2_01"], ["traffic_category_city_category_browse_experiment", "category_city_0"], ["traffic_remove_canonical_links_on_paginated_pages", "no_canonical_1"], ["traffic_nearme_redesign_experiment", "redesign_0"], ["traffic_biz_details_title_v6_transactions_v3", "conditions_1"]];\n\n\n            (function(H){H.className=H.className.replace(/\\bno-js\\b/,\'js\');})(document.documentElement);\n\n            pageSpeedCustomTimesta ...

# %% [markdown]
# #wrap > div.main-content-wrap.main-content-wrap--full > yelp-react-root > div > div.margin-t3__373c0__1l90z.margin-b6__373c0__2Azj6.border-color--default__373c0__3-ifU > div > div > div.margin-b3__373c0__q1DuY.border-color--default__373c0__3-ifU > section:nth-child(2) > div
#
# <div class=" alert-container__373c0__2_UFV border-color--default__373c0__3-ifU" aria-label="Error" role="alert"><div class=" alert__373c0__2W4cB page__373c0__3A_bx error__373c0__1doYa high__373c0__3qeSp arrange__373c0__2C9bH vertical-align-middle__373c0__1SDTo border-color--default__373c0__3-ifU"><div class=" alert-icon-unit__373c0__2WHUe arrange-unit__373c0__o3tjT border-color--default__373c0__3-ifU"><div class=" alert-icon-container__373c0__2Vlsq border-color--default__373c0__3-ifU"><div class=" alert-icon__373c0__5A99z border-color--default__373c0__3-ifU"><span aria-hidden="true" class="icon--24-exclamation-v2 css-p5yz4n"><svg xmlns="http://www.w3.org/2000/svg" width="24" height="24" class="icon_svg"><path d="M12 1c6.075 0 11 4.925 11 11a11 11 0 01-11 11C5.925 23 1 18.075 1 12S5.925 1 12 1zm0 2a9 9 0 100 18 9 9 0 000-18zm0 11.39a1.5 1.5 0 110 3 1.5 1.5 0 010-3zm0-8.78a1 1 0 011 1v5.63a1 1 0 11-2 0V6.61a1 1 0 011-1z"></path></svg></span></div></div></div><div class=" arrange-unit__373c0__o3tjT arrange-unit-fill__373c0__3Sfw1 border-color--default__373c0__3-ifU"><span class=" text__373c0__2Kxyz text-color--normal__373c0__3xep9 text-align--left__373c0__2XGa- text-size--inherit__373c0__2fB3p"><div class=" alert__373c0__2xCbt border-color--default__373c0__3-ifU"><p class=" text__373c0__2Kxyz text-color--normal__373c0__3xep9 text-align--left__373c0__2XGa- text-size--inherit__373c0__2fB3p"><span class=" text__373c0__2Kxyz text-color--normal__373c0__3xep9 text-align--left__373c0__2XGa- text-weight--bold__373c0__1elNz text-size--large__373c0__3t60B"><span class=" raw__373c0__3rcx7">Yelpers report this location has closed.</span></span> <span class=" text__373c0__2Kxyz text-color--normal__373c0__3xep9 text-align--left__373c0__2XGa- text-size--large__373c0__3t60B"><span class=" raw__373c0__3rcx7">Find a <a href="/search?cflt=tattoo&amp;find_desc=&amp;find_loc=Las+Vegas%2C+NV">similar spot</a>.</span></span></p></div></span></div></div></div>

# %%
s = soup.find_all(
    "span", {"class": "raw__373c0__3rcx7"})

s
# Out:
# []

# %% [markdown]
# ### Notes

# %%
# Read in data
yelp_business_path = "../data/yelp_dataset/yelp_academic_dataset_business.json"
yelp_b_df = pd.read_json(yelp_business_path, lines=True)

# %%
# Concat name and city together
df = yelp_b_df[["name", "city"]].copy()
df["combined"] = yelp_b_df["name"] + " " + yelp_b_df["city"]

# This is the function for stripping values that we are working on
df["combined"] = df["combined"].str.strip(".-,")
df.head()
# Out:
#                        name             city  \
# 0  The Range At Lake Norman        Cornelius
# 1         Carlos Santo, NMD       Scottsdale
# 2                   Felinus         Montreal
# 3      Nevada House of Hose  North Las Vegas
# 4   USE MY GUY SERVICES LLC             Mesa
#
#                                combined
# 0    The Range At Lake Norman Cornelius
# 1          Carlos Santo, NMD Scottsdale
# 2                      Felinus Montreal
# 3  Nevada House of Hose North Las Vegas
# 4          USE MY GUY SERVICES LLC Mesa

# %%
# Save the data
# df.to_csv("web_scrape_names.csv")

# %%
# https://www.yelp.com/biz/big-chickie-seattle

# The pandas apply function to append to the list
ls = []

# Emily thoughts
# chars to take care of : 
# & --> and
# + --> - / omit  
# ' --> omit
# "-" --> stays
# . --> omit / -
# , --> omit 
# / --> hyphen 
#       need to check for the presence of / in each word and replace with -
#       need to omit if it's the first char in url
# - --> stay
# array to hold characters we need to omit 
#    delete = [""]

def ls_maker(x): 
    web_string = f"https://www.yelp.com/biz/{str(x).replace(' ', '-')}"
    ls.append(web_string)
    return

df["biz_city"].apply(ls_maker)

# %%
# Out:
# "Hi'S"

# %% [markdown]
# <p class="lemon--p__373c0__3Qnnj text__373c0__2Kxyz text-color--normal__373c0__3xep9 text-align--left__373c0__2XGa- text-size--inherit__373c0__2fB3p"><span class="lemon--span__373c0__3997G text__373c0__2Kxyz text-color--normal__373c0__3xep9 text-align--left__373c0__2XGa- text-weight--bold__373c0__1elNz text-size--large__373c0__3t60B"><span class="lemon--span__373c0__3997G raw__373c0__3rcx7">Yelpers report this location has closed.</span></span> <span class="lemon--span__373c0__3997G text__373c0__2Kxyz text-color--normal__373c0__3xep9 text-align--left__373c0__2XGa- text-size--large__373c0__3t60B"><span class="lemon--span__373c0__3997G raw__373c0__3rcx7">Find a <a href="/search?cflt=tattoo&amp;find_desc=&amp;find_loc=Las+Vegas%2C+NV">similar spot</a>.</span></span></p>
